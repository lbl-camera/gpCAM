# %% [markdown]
# ## Single-Task GP AE Test

# %%
#/usr/bin/env python
import numpy as np
from gpcam.autonomous_experimenter import AutonomousExperimenterGP

def instrument(data):
    for entry in data:
        entry["value"] = np.sin(np.linalg.norm(entry["position"]))
    return data

my_ae = AutonomousExperimenterGP(np.array([[0,10],[0,10]]),instrument,
                                 np.ones((3)),np.array([[0.001,100],[0.001,100],[0.001,100]]),
                                 init_dataset_size= 10)
my_ae.train()
input("training done")
my_ae.go(N = 200)
# Out:
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# GP successfully initiated
# Costs successfully initialized
# ##################################################################################
# Initialization successfully concluded
# now train(...) or train_async(...), and then go(...)
# ##################################################################################
# GP training started with  10  data points
# Hyper-parameter tuning in progress. Old hyper-parameters:  [1. 1. 1.]  with old log likelihood:  11.418212494346509
# method:  global
# I am performing a global differential evolution algorithm to find the optimal hyperparameters.
# maximum number of iterations:  20
# termination tolerance:  1e-06
# bounds:  [[1.e-03 1.e+02]
#  [1.e-03 1.e+02]
#  [1.e-03 1.e+02]]
# differential_evolution step 1: f(x)= 11.1426
# differential_evolution step 2: f(x)= 11.1426
# differential_evolution step 3: f(x)= 11.1426
# differential_evolution step 4: f(x)= 11.1426
# differential_evolution step 5: f(x)= 10.985
# differential_evolution step 6: f(x)= 10.985
# differential_evolution step 7: f(x)= 10.985
# differential_evolution step 8: f(x)= 10.9421
# differential_evolution step 9: f(x)= 10.616
# differential_evolution step 10: f(x)= 10.616
# differential_evolution step 11: f(x)= 10.616
# differential_evolution step 12: f(x)= 10.1086
# differential_evolution step 13: f(x)= 9.36391
# differential_evolution step 14: f(x)= 9.36391
# differential_evolution step 15: f(x)= 9.36391
# differential_evolution step 16: f(x)= 9.36391
# differential_evolution step 17: f(x)= 9.36391
# differential_evolution step 18: f(x)= 9.36391
# differential_evolution step 19: f(x)= 9.36391
# differential_evolution step 20: f(x)= 9.36391
# I found hyper-parameters  [0.456661   5.43574411 0.83448989]  with likelihood  8.96541273564658  via global optimization
# training done
# Date and time:        2021-05-17_15_11_00
#
#
#
# ====================
# ====================
# iteration:  10
# Run Time:  0.00024771690368652344      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  1e-06
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.665544
# differential_evolution step 2: f(x)= -0.665544
# differential_evolution step 3: f(x)= -0.666337
# differential_evolution step 4: f(x)= -0.666505
# differential_evolution step 5: f(x)= -0.666505
# differential_evolution step 6: f(x)= -0.666764
# differential_evolution step 7: f(x)= -0.666764
# differential_evolution step 8: f(x)= -0.666764
# differential_evolution step 9: f(x)= -0.666764
# differential_evolution step 10: f(x)= -0.666764
# differential_evolution step 11: f(x)= -0.666764
# differential_evolution step 12: f(x)= -0.666764
# differential_evolution step 13: f(x)= -0.666764
# differential_evolution step 14: f(x)= -0.667127
# differential_evolution step 15: f(x)= -0.667146
# differential_evolution step 16: f(x)= -0.667146
# differential_evolution step 17: f(x)= -0.66717
# differential_evolution step 18: f(x)= -0.667285
# differential_evolution step 19: f(x)= -0.667285
# differential_evolution step 20: f(x)= -0.667297
# variance optimization tolerance of changed to:  0.06672974598548166
# Next points to be requested:
# [[9.98439017e+00 1.58529779e-03]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  11
# Run Time:  0.20140504837036133      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06672974598548166
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06385261250473168
# Next points to be requested:
# [[4.45357286 0.04053305]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  12
# Run Time:  0.21045708656311035      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06385261250473168
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.665544
# differential_evolution step 2: f(x)= -0.665571
# variance optimization tolerance of changed to:  0.06655705470327948
# Next points to be requested:
# [[9.70693743 0.07494625]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  13
# Run Time:  0.2365882396697998      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06655705470327948
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06306455745041888
# Next points to be requested:
# [[3.68794991 5.58881495]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  14
# Run Time:  0.24230623245239258      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06306455745041888
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.665202
# differential_evolution step 2: f(x)= -0.665202
# variance optimization tolerance of changed to:  0.06652020089818143
# Next points to be requested:
# [[9.43951822 2.78628505]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  15
# Run Time:  0.26537275314331055      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06652020089818143
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.05971706223075557
# Next points to be requested:
# [[0.         6.39785878]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  16
# Run Time:  0.2725944519042969      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.05971706223075557
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.663687
# differential_evolution step 2: f(x)= -0.666153
# variance optimization tolerance of changed to:  0.06661534358329857
# Next points to be requested:
# [[9.67924114 2.57896414]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  17
# Run Time:  0.30008816719055176      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06661534358329857
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.05669140725203518
# Next points to be requested:
# [[9.85945459 4.9566017 ]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  18
# Run Time:  0.30469489097595215      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.05669140725203518
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.666088
# differential_evolution step 2: f(x)= -0.666088
# variance optimization tolerance of changed to:  0.06660880985055848
# Next points to be requested:
# [[9.63249742 2.62313149]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  19
# Run Time:  0.3279688358306885      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06660880985055848
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06298796355664389
# Next points to be requested:
# [[3.8906869  8.62176995]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  20
# Run Time:  0.3330411911010742      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06298796355664389
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.665608
# differential_evolution step 2: f(x)= -0.665608
# variance optimization tolerance of changed to:  0.06656076620317168
# Next points to be requested:
# [[9.85259704 2.82830976]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  21
# Run Time:  0.36241579055786133      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06656076620317168
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06286459560258183
# Next points to be requested:
# [[3.05599313 8.04705496]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  22
# Run Time:  0.36843204498291016      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06286459560258183
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.660583
# variance optimization tolerance of changed to:  0.06605832616520978
# Next points to be requested:
# [[7.88276943 2.93674314]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  23
# Run Time:  0.38394641876220703      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06605832616520978
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.062064701233781494
# Next points to be requested:
# [[1.86092209 0.06412147]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  24
# Run Time:  0.38924646377563477      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.062064701233781494
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.666402
# differential_evolution step 2: f(x)= -0.666402
# differential_evolution step 3: f(x)= -0.666721
# differential_evolution step 4: f(x)= -0.666721
# variance optimization tolerance of changed to:  0.06667206113369951
# Next points to be requested:
# [[9.97978376 0.04739215]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  25
# Run Time:  0.4305276870727539      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06667206113369951
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06335793083192817
# Next points to be requested:
# [[7.78175485 3.54193789]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  26
# Run Time:  0.43620944023132324      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06335793083192817
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.666121
# variance optimization tolerance of changed to:  0.06661210003575521
# Next points to be requested:
# [[9.817134   2.47239922]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  27
# Run Time:  0.4623711109161377      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06661210003575521
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06345314313785815
# Next points to be requested:
# [[1.64556972 3.22240239]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  28
# Run Time:  0.4681401252746582      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06345314313785815
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.661183
# differential_evolution step 2: f(x)= -0.664897
# differential_evolution step 3: f(x)= -0.664897
# variance optimization tolerance of changed to:  0.06648965029705783
# Next points to be requested:
# [[9.03396827 2.58364804]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  29
# Run Time:  0.502598762512207      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06648965029705783
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.05486038812408104
# Next points to be requested:
# [[3.35866185 0.52254486]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  30
# Run Time:  0.5083427429199219      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.05486038812408104
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.664133
# differential_evolution step 2: f(x)= -0.665678
# variance optimization tolerance of changed to:  0.06656783995482057
# Next points to be requested:
# [[9.41352593 2.6374884 ]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  31
# Run Time:  0.5381600856781006      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06656783995482057
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.0635388574286781
# Next points to be requested:
# [[2.08617409 8.15625432]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  32
# Run Time:  0.543917179107666      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.0635388574286781
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.666147
# differential_evolution step 2: f(x)= -0.666147
# variance optimization tolerance of changed to:  0.06661466702876102
# Next points to be requested:
# [[9.84692849 0.06314307]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  33
# Run Time:  0.5727498531341553      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06661466702876102
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.05489406416726661
# Next points to be requested:
# [[3.8783528  9.69144987]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  34
# Run Time:  0.5773122310638428      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.05489406416726661
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.66327
# differential_evolution step 2: f(x)= -0.66327
# variance optimization tolerance of changed to:  0.06632696959233353
# Next points to be requested:
# [[8.20618005 2.62275   ]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  35
# Run Time:  0.600714921951294      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06632696959233353
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06519730904529428
# Next points to be requested:
# [[4.98736967 2.41043268]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  36
# Run Time:  0.6050488948822021      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06519730904529428
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.666541
# differential_evolution step 2: f(x)= -0.666541
# variance optimization tolerance of changed to:  0.066654146809794
# Next points to be requested:
# [[9.8934266 2.6417182]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  37
# Run Time:  0.627770185470581      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.066654146809794
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.060094671937926405
# Next points to be requested:
# [[4.79893364 8.9077994 ]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  38
# Run Time:  0.6324067115783691      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.060094671937926405
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.665908
# differential_evolution step 2: f(x)= -0.665908
# variance optimization tolerance of changed to:  0.06659081151940023
# Next points to be requested:
# [[9.55251995 0.01924318]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  39
# Run Time:  0.6564035415649414      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06659081151940023
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06391920994182419
# Next points to be requested:
# [[3.55180406 2.23698181]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  40
# Run Time:  0.66190505027771      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06391920994182419
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.66602
# differential_evolution step 2: f(x)= -0.66602
# variance optimization tolerance of changed to:  0.06660203517221898
# Next points to be requested:
# [[9.72102443 0.045774  ]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  41
# Run Time:  0.7141227722167969      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06660203517221898
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06259016807423279
# Next points to be requested:
# [[3.81040286 3.3764879 ]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  42
# Run Time:  0.7298915386199951      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06259016807423279
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.666025
# differential_evolution step 2: f(x)= -0.666025
# variance optimization tolerance of changed to:  0.0666025335760675
# Next points to be requested:
# [[9.60995803 2.58147274]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  43
# Run Time:  0.7662715911865234      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.0666025335760675
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.04599304886931622
# Next points to be requested:
# [[ 6.46746974 10.        ]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  44
# Run Time:  0.7712759971618652      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.04599304886931622
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.661323
# differential_evolution step 2: f(x)= -0.66489
# variance optimization tolerance of changed to:  0.06648903523913895
# Next points to be requested:
# [[9.01249985 2.67337011]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  45
# Run Time:  0.7958335876464844      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06648903523913895
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06201048967206864
# Next points to be requested:
# [[5.42070121 3.53216965]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  46
# Run Time:  0.8014109134674072      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06201048967206864
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.6645
# variance optimization tolerance of changed to:  0.06644995152910242
# Next points to be requested:
# [[8.85378407 2.5739897 ]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  47
# Run Time:  0.8179230690002441      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06644995152910242
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06097126234454872
# Next points to be requested:
# [[4.99914047 6.32351814]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  48
# Run Time:  0.8236842155456543      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06097126234454872
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.66435
# variance optimization tolerance of changed to:  0.0664350244939188
# Next points to be requested:
# [[8.79852453 2.56419024]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  49
# Run Time:  0.8407151699066162      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.0664350244939188
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06399194545498155
# Next points to be requested:
# [[2.323787   3.16061688]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  50
# Run Time:  0.8464865684509277      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06399194545498155
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.662239
# variance optimization tolerance of changed to:  0.06622394844427018
# Next points to be requested:
# [[9.49245452 2.15968997]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  51
# Run Time:  0.8632657527923584      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06622394844427018
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# ...
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06304249722991494
# Next points to be requested:
# [[3.1454702  5.98499246]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  186
# Run Time:  3.2253170013427734      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06304249722991494
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.664632
# differential_evolution step 2: f(x)= -0.664632
# variance optimization tolerance of changed to:  0.0664631645894809
# Next points to be requested:
# [[8.98559538 2.53451732]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  187
# Run Time:  3.2552199363708496      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.0664631645894809
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06061775533401188
# Next points to be requested:
# [[5.41937727 1.78861518]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  188
# Run Time:  3.2634427547454834      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06061775533401188
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.664302
# differential_evolution step 2: f(x)= -0.665036
# variance optimization tolerance of changed to:  0.06650359100086538
# Next points to be requested:
# [[9.2286767 2.750289 ]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  189
# Run Time:  3.292520046234131      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06650359100086538
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06461136066917038
# Next points to be requested:
# [[8.19490993 0.55660015]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  190
# Run Time:  3.299867868423462      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06461136066917038
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.666737
# differential_evolution step 2: f(x)= -0.666737
# variance optimization tolerance of changed to:  0.06667370906280541
# Next points to be requested:
# [[9.90122922 0.02943786]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  191
# Run Time:  3.3264877796173096      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06667370906280541
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.062409736738304224
# Next points to be requested:
# [[1.09763776 0.03116316]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  192
# Run Time:  3.3337748050689697      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.062409736738304224
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.666086
# variance optimization tolerance of changed to:  0.06660864191043878
# Next points to be requested:
# [[9.98689647 2.39671497]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  193
# Run Time:  3.351808547973633      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06660864191043878
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06518783982121894
# Next points to be requested:
# [[9.26892537 6.33668247]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  194
# Run Time:  3.358293056488037      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06518783982121894
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.66183
# differential_evolution step 2: f(x)= -0.66193
# variance optimization tolerance of changed to:  0.0661930475253361
# Next points to be requested:
# [[7.57824035 2.73691739]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  195
# Run Time:  3.3827693462371826      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.0661930475253361
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06200280052467172
# Next points to be requested:
# [[6.0114588  8.38136389]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  196
# Run Time:  3.3889434337615967      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06200280052467172
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.661497
# differential_evolution step 2: f(x)= -0.664176
# variance optimization tolerance of changed to:  0.06641755954178162
# Next points to be requested:
# [[8.77470051 2.53542087]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  197
# Run Time:  3.414520740509033      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06641755954178162
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.060424211350560114
# Next points to be requested:
# [[3.9770868  0.30814533]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  198
# Run Time:  3.4216020107269287      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.060424211350560114
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.66658
# differential_evolution step 2: f(x)= -0.66658
# variance optimization tolerance of changed to:  0.0666579626151599
# Next points to be requested:
# [[9.97543099 2.51140007]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  199
# Run Time:  3.4724860191345215      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.0666579626151599
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06367363255032053
# Next points to be requested:
# [[0.02133215 8.10693204]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
# ====================================================
# The autonomous experiment was concluded successfully
# ====================================================

# %% [markdown]
# ## Multi-Task GP AE Test

# %%
#/usr/bin/env python
import numpy as np
from gpcam.autonomous_experimenter import AutonomousExperimenterfvGP

def instrument(data):
    for entry in data:
        entry["value"] = np.array([np.sin(np.linalg.norm(entry["position"])),np.sin(np.linalg.norm(entry["position"]))])
    return data

my_fvae = AutonomousExperimenterfvGP(np.array([[0,10],[0,10]]),2,1,
                                     instrument,np.ones((3)),np.array([[0.001,100],[0.001,100],[0.001,100]]),
                                     init_dataset_size= 10)
my_fvae.train()
input("training done")
my_ae.go(N = 200)
# Out:
# CAUTION: you have not provided data variances, they will set to be 1 percent of the data values!
# Costs successfully initialized
# ##################################################################################
# Initialization successfully concluded
# now train(...) or train_async(...), and then go(...)
# ##################################################################################
# GP training started with  20  data points
# Hyper-parameter tuning in progress. Old hyper-parameters:  [1. 1. 1.]  with old log likelihood:  nan
# method:  global
# I am performing a global differential evolution algorithm to find the optimal hyperparameters.
# maximum number of iterations:  20
# termination tolerance:  1e-06
# bounds:  [[1.e-03 1.e+02]
#  [1.e-03 1.e+02]
#  [1.e-03 1.e+02]]
# differential_evolution step 1: f(x)= nan
# differential_evolution step 2: f(x)= nan
# differential_evolution step 3: f(x)= nan
# differential_evolution step 4: f(x)= nan
# differential_evolution step 5: f(x)= nan
# differential_evolution step 6: f(x)= nan
# differential_evolution step 7: f(x)= nan
# differential_evolution step 8: f(x)= nan
# differential_evolution step 9: f(x)= nan
# differential_evolution step 10: f(x)= nan
# differential_evolution step 11: f(x)= nan
# differential_evolution step 12: f(x)= nan
# differential_evolution step 13: f(x)= nan
# differential_evolution step 14: f(x)= nan
# differential_evolution step 15: f(x)= nan
# differential_evolution step 16: f(x)= nan
# differential_evolution step 17: f(x)= nan
# differential_evolution step 18: f(x)= nan
# differential_evolution step 19: f(x)= nan
# differential_evolution step 20: f(x)= nan
# I found hyper-parameters  [ 4.58490202 71.11226116 66.9284315 ]  with likelihood  nan  via global optimization
# training done
# Date and time:        2021-05-17_15_11_08
#
#
#
# ====================
# ====================
# iteration:  10
# Run Time:  0.0004107952117919922      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  1e-06
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.666949
# differential_evolution step 2: f(x)= -0.666949
# differential_evolution step 3: f(x)= -0.666949
# differential_evolution step 4: f(x)= -0.666949
# differential_evolution step 5: f(x)= -0.666949
# differential_evolution step 6: f(x)= -0.666949
# differential_evolution step 7: f(x)= -0.666949
# differential_evolution step 8: f(x)= -0.666949
# differential_evolution step 9: f(x)= -0.666949
# differential_evolution step 10: f(x)= -0.666949
# differential_evolution step 11: f(x)= -0.666949
# differential_evolution step 12: f(x)= -0.666949
# differential_evolution step 13: f(x)= -0.666949
# differential_evolution step 14: f(x)= -0.667011
# differential_evolution step 15: f(x)= -0.667011
# differential_evolution step 16: f(x)= -0.667064
# differential_evolution step 17: f(x)= -0.667064
# differential_evolution step 18: f(x)= -0.667248
# differential_evolution step 19: f(x)= -0.667248
# differential_evolution step 20: f(x)= -0.667248
# variance optimization tolerance of changed to:  0.06672477504296123
# Next points to be requested:
# [[9.96385706e+00 1.45499768e-03]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  11
# Run Time:  0.18946552276611328      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06672477504296123
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06326788034067214
# Next points to be requested:
# [[5.03721849 3.37448214]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  12
# Run Time:  0.19803357124328613      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06326788034067214
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.665317
# differential_evolution step 2: f(x)= -0.665317
# variance optimization tolerance of changed to:  0.06653173310939929
# Next points to be requested:
# [[9.44799596 2.46982538]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  13
# Run Time:  0.22661042213439941      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06653173310939929
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.063763393695835
# Next points to be requested:
# [[2.7193728  8.74242528]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  14
# Run Time:  0.23637962341308594      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.063763393695835
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.663714
# variance optimization tolerance of changed to:  0.06637135656439169
# Next points to be requested:
# [[8.98314738 2.40425369]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  15
# Run Time:  0.25820112228393555      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06637135656439169
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.060281966852425
# Next points to be requested:
# [[6.02068589 7.41967909]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  16
# Run Time:  0.26535654067993164      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.060281966852425
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.666212
# differential_evolution step 2: f(x)= -0.666212
# variance optimization tolerance of changed to:  0.06662122554586679
# Next points to be requested:
# [[9.90947893 2.45032126]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  17
# Run Time:  0.2960629463195801      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06662122554586679
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.061783119993249584
# Next points to be requested:
# [[6.11569815 7.59470084]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  18
# Run Time:  0.3042111396789551      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.061783119993249584
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.663317
# differential_evolution step 2: f(x)= -0.664177
# variance optimization tolerance of changed to:  0.06641769627759592
# Next points to be requested:
# [[8.75345469 2.5455443 ]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  19
# Run Time:  0.32880663871765137      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06641769627759592
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.060365713612159345
# Next points to be requested:
# [[5.35122785 1.77879114]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  20
# Run Time:  0.33699893951416016      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.060365713612159345
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.666112
# differential_evolution step 2: f(x)= -0.666112
# differential_evolution step 3: f(x)= -0.666112
# variance optimization tolerance of changed to:  0.06661120651073982
# Next points to be requested:
# [[9.94243593 0.08657951]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  21
# Run Time:  0.3721926212310791      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06661120651073982
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06169077304992319
# Next points to be requested:
# [[8.42458318 8.24078567]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  22
# Run Time:  0.38024473190307617      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06169077304992319
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.663005
# variance optimization tolerance of changed to:  0.06630052151903129
# Next points to be requested:
# [[8.29247585 2.79703065]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  23
# Run Time:  0.399289608001709      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06630052151903129
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06594051913544112
# Next points to be requested:
# [[7.54994542 2.96388611]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  24
# Run Time:  0.4075009822845459      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06594051913544112
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.664867
# differential_evolution step 2: f(x)= -0.665637
# variance optimization tolerance of changed to:  0.06656368341489503
# Next points to be requested:
# [[9.39524063 2.60115416]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  25
# Run Time:  0.43551015853881836      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06656368341489503
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06442513007643091
# Next points to be requested:
# [[6.66293562 2.06582047]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  26
# Run Time:  0.44260668754577637      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06442513007643091
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.664265
# differential_evolution step 2: f(x)= -0.664265
# variance optimization tolerance of changed to:  0.06642650959780513
# Next points to be requested:
# [[8.93818836 2.48657745]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  27
# Run Time:  0.4687504768371582      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06642650959780513
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.05578856358301263
# Next points to be requested:
# [[5.59516738 1.20969665]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  28
# Run Time:  0.4757382869720459      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.05578856358301263
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.661819
# differential_evolution step 2: f(x)= -0.66445
# variance optimization tolerance of changed to:  0.06644500459074985
# Next points to be requested:
# [[8.91859255 2.75409009]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  29
# Run Time:  0.5539214611053467      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06644500459074985
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06651368217886382
# Next points to be requested:
# [[9.43048561 2.79353523]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  30
# Run Time:  0.564227819442749      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06651368217886382
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.665604
# differential_evolution step 2: f(x)= -0.665604
# variance optimization tolerance of changed to:  0.06656043836668483
# Next points to be requested:
# [[9.37531062 2.60843942]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  31
# Run Time:  0.5921535491943359      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06656043836668483
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06498338813942246
# Next points to be requested:
# [[7.66425249 0.30701223]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  32
# Run Time:  0.5999021530151367      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06498338813942246
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.663429
# variance optimization tolerance of changed to:  0.06634290507205791
# Next points to be requested:
# [[9.22965602 0.10972715]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  33
# Run Time:  0.6195113658905029      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06634290507205791
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06442511184213241
# Next points to be requested:
# [[3.55059742 2.31487317]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  34
# Run Time:  0.6282896995544434      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06442511184213241
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.663456
# differential_evolution step 2: f(x)= -0.663456
# variance optimization tolerance of changed to:  0.06634562047114238
# Next points to be requested:
# [[9.44548948 2.95369474]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  35
# Run Time:  0.6633358001708984      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06634562047114238
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.0578229289333987
# Next points to be requested:
# [[6.05588264 1.16050144]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  36
# Run Time:  0.6704490184783936      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.0578229289333987
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.660927
# differential_evolution step 2: f(x)= -0.665672
# variance optimization tolerance of changed to:  0.06656719920805358
# Next points to be requested:
# [[9.62237108 2.46488878]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  37
# Run Time:  0.6958258152008057      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06656719920805358
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06312569028294727
# Next points to be requested:
# [[8.06567798 8.06534718]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  38
# Run Time:  0.7044544219970703      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06312569028294727
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.663322
# variance optimization tolerance of changed to:  0.06633217457452553
# Next points to be requested:
# [[8.22628925 2.6276577 ]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  39
# Run Time:  0.7223246097564697      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06633217457452553
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.04725700282469111
# Next points to be requested:
# [[8.61798979 9.51548537]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  40
# Run Time:  0.7298269271850586      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.04725700282469111
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.665833
# differential_evolution step 2: f(x)= -0.665833
# variance optimization tolerance of changed to:  0.06658325166399857
# Next points to be requested:
# [[9.51144582 2.66187226]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  41
# Run Time:  0.7577862739562988      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06658325166399857
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.0642821108862668
# Next points to be requested:
# [[7.81829613 6.26522774]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  42
# Run Time:  0.7659151554107666      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.0642821108862668
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.665983
# differential_evolution step 2: f(x)= -0.665983
# variance optimization tolerance of changed to:  0.06659833504039525
# Next points to be requested:
# [[9.58366697 2.58828916]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  43
# Run Time:  0.7920444011688232      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06659833504039525
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.0634933559628696
# Next points to be requested:
# [[1.95556734 5.90024269]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  44
# Run Time:  0.8009033203125      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.0634933559628696
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.665016
# differential_evolution step 2: f(x)= -0.665016
# variance optimization tolerance of changed to:  0.06650155794928296
# Next points to be requested:
# [[9.745472   0.12208431]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
# ====================
# ====================
# iteration:  45
# Run Time:  0.8282482624053955      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06650155794928296
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06460967308722793
# Next points to be requested:
# [[3.76169075 3.10192608]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  46
# Run Time:  0.8422670364379883      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06460967308722793
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.664226
# differential_evolution step 2: f(x)= -0.664226
# variance optimization tolerance of changed to:  0.06642259528541528
# Next points to be requested:
# [[9.98160558 2.97076841]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  47
# Run Time:  0.8674921989440918      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06642259528541528
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06369123975053895
# Next points to be requested:
# [[2.759549  8.7567488]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  48
# Run Time:  0.8809351921081543      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06369123975053895
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.665173
# differential_evolution step 2: f(x)= -0.665173
# variance optimization tolerance of changed to:  0.06651734733051419
# Next points to be requested:
# [[9.47407601 0.0531699 ]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  49
# Run Time:  0.9090292453765869      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06651734733051419
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06279574140450155
# Next points to be requested:
# [[3.16383205 5.52717469]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  50
# Run Time:  0.9181966781616211      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06279574140450155
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.663805
# differential_evolution step 2: f(x)= -0.66413
# variance optimization tolerance of changed to:  0.06641302150972271
# Next points to be requested:
# [[9.93028461 2.19216867]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  51
# Run Time:  0.9452300071716309      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06641302150972271
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06193137219974263
# Next points to be requested:
# [[8.76391479 8.21154395]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# ...
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06048334632261292
# Next points to be requested:
# [[3.69889552 3.53881735]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  186
# Run Time:  4.008392572402954      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06048334632261292
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.660634
# differential_evolution step 2: f(x)= -0.663608
# variance optimization tolerance of changed to:  0.06636082049711355
# Next points to be requested:
# [[9.57759961 0.17609204]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  187
# Run Time:  4.037184953689575      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06636082049711355
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06484367370026344
# Next points to be requested:
# [[2.59574216 3.00859216]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  188
# Run Time:  4.048826217651367      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06484367370026344
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.664434
# variance optimization tolerance of changed to:  0.06644342233914087
# Next points to be requested:
# [[9.10186903 0.02526848]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  189
# Run Time:  4.071019411087036      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06644342233914087
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06287141664318849
# Next points to be requested:
# [[2.19007639 8.05457544]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  190
# Run Time:  4.08373761177063      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06287141664318849
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.664388
# differential_evolution step 2: f(x)= -0.664388
# variance optimization tolerance of changed to:  0.06643884127765903
# Next points to be requested:
# [[8.76036682 2.60755183]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  191
# Run Time:  4.11801815032959      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06643884127765903
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.05736630566879134
# Next points to be requested:
# [[5.65421317 0.96594324]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  192
# Run Time:  4.129374980926514      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.05736630566879134
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.665881
# differential_evolution step 2: f(x)= -0.666289
# differential_evolution step 3: f(x)= -0.666289
# variance optimization tolerance of changed to:  0.06662891484381699
# Next points to be requested:
# [[9.77243647 2.66671667]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  193
# Run Time:  4.170217752456665      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06662891484381699
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06397836343694828
# Next points to be requested:
# [[9.64360267 7.95015297]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  194
# Run Time:  4.185134172439575      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06397836343694828
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.666163
# differential_evolution step 2: f(x)= -0.666163
# variance optimization tolerance of changed to:  0.06661633677162924
# Next points to be requested:
# [[9.68607552 2.57660405]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  195
# Run Time:  4.213635683059692      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06661633677162924
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06508370016424876
# Next points to be requested:
# [[3.70833096 2.45597592]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  196
# Run Time:  4.223982810974121      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06508370016424876
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.664279
# differential_evolution step 2: f(x)= -0.664279
# variance optimization tolerance of changed to:  0.06642790965540944
# Next points to be requested:
# [[9.47683326 2.89531618]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  197
# Run Time:  4.25578236579895      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06642790965540944
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.06389931253011626
# Next points to be requested:
# [[1.06493576 5.83039207]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  198
# Run Time:  4.284764051437378      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  global
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  global
# adjusted tolerance:  0.06389931253011626
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# differential_evolution step 1: f(x)= -0.662809
# differential_evolution step 2: f(x)= -0.663584
# variance optimization tolerance of changed to:  0.06635836919474646
# Next points to be requested:
# [[9.15066976 2.90271859]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
#
#
#
# ====================
# ====================
# iteration:  199
# Run Time:  4.340045928955078      seconds
# Number of measurements:  10
# ====================
# aks() initiated with hyperparameters: [0.456661   5.43574411 0.83448989]
# optimization method:  local
# bounds:  None
# ====================================
# finding acquisition function maxima...
# optimization method  local
# adjusted tolerance:  0.06635836919474646
# population size:  20
# maximum number of iterations:  20
# bounds:
# [[ 0 10]
#  [ 0 10]]
# cost function parameters:  {}
# ====================================
# variance optimization tolerance of changed to:  0.05750263864169297
# Next points to be requested:
# [[5.73673197 8.94734515]]
# CAUTION: you have not provided data variances,
# they will set to be 1 percent of the the data values!
# Async Hyper-parameter update not successful. I am keeping the old ones.
# That probbaly means you are not optimizing them asynchronously
# hyperparameters:  [0.456661   5.43574411 0.83448989]
# No training in this round but I tried to update the hyperparameters
# ====================================================
# The autonomous experiment was concluded successfully
# ====================================================
