# %% [markdown]
# # gp2Scale
# gp2Scale is a special setting in gpCAM that combines non-stationary, compactly-supported kernels, HPC distributed computing, and sparse random linear algebra to allow scale-up of exact GPs to millions of data points. Here we run a moderately-sized GP, just because we assume you might run this locally.
#
# I hope it is clear how cool it is what is happening here. If you have a dask client that points to a remote cluster with 500 GPUs, you will distribute the covariance matrix computation across those. The full matrix is sparse and will be fast to work with in downstream operations. The algorithm only makes use of naturally-occuring sparsity, so the result is exact in contrast to Vecchia or inducing-point methods.

# %%
##first install the newest version of fvgp
#!pip install gpcam==8.0.0

# %% [markdown]
# ## Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
from gpcam import GPOptimizer
from dask.distributed import Client
# %load_ext autoreload
# %autoreload 2

client = Client() ##this is the client you can make locally like this or 
#your HPC team can provide a script to get it. We included an example to get gp2Scale going
#on NERSC's Perlmutter


#It's good practice to make sure to wait for all the workers to be ready
client.wait_for_workers(4)

# %% [markdown]
# ## Preparing the data and some other inputs

# %%
def f1(x):
    return ((np.sin(5. * x) + np.cos(10. * x) + (2.* (x-0.4)**2) * np.cos(100. * x)))

input_dim = 1
N = 10000
x_data = np.random.rand(N,input_dim)
y_data = f1(x_data)
hps_n = 2

hps_bounds = np.array([[0.1,10.],      ##signal var of Wendland kernel
                       [0.001,0.02]])  ##length scale for Wendland kernel

# %%
init_hps = np.random.uniform(size = len(hps_bounds), low = hps_bounds[:,0], high = hps_bounds[:,1])

my_gp2S = GPOptimizer(x_data,y_data,init_hyperparameters=init_hps, 
            gp2Scale = True, gp2Scale_batch_size= 1000, gp2Scale_dask_client = client, info = True
            )

my_gp2S.train(hps_bounds, max_iter = 2)
# Out:
# Transferring the covariance matrix to host done after  1.8286995887756348  seconds. sparsity =  0.01816512
# MINRES solve in progress ... 1.913729190826416 seconds.
# MINRES solve done after  2.126354455947876 seconds.
# logdet() in progress ...  2.126406192779541 seconds.
#                                     results
# ==============================================================================
#      inquiries                            error            samples
# --------------------              ---------------------   ---------
# i         parameters       trace    absolute   relative   num   out  converged
# ==============================================================================
# 1               none  -3.542e+04   9.548e+01     0.270%   100     0      False
#
#                                     config
# ==============================================================================
#                 matrix                            stochastic estimator
# -------------------------------------    -------------------------------------
# gram:                           False    method:                           slq
# exponent:                           1    lanczos degree:                    20
# num matrix parameters:              0    lanczos tol:                2.220e-16
# data type:                     64-bit    orthogonalization:               none
#
#              convergence                                 error
# -------------------------------------    -------------------------------------
# min num samples:                   10    abs error tol:              0.000e+00
# max num samples:                  100    rel error tol:                  10.00%
# outlier significance level:     0.00%    confidence level:              95.00%
#
#                                    process
# ==============================================================================
#                  time                                   device
# -------------------------------------    -------------------------------------
# tot wall time (sec):        5.526e-01    num cpu threads:                   16
# alg wall time (sec):        5.456e-01    num gpu devices, multiproc:     0,  0
# cpu proc time (sec):        7.509e+00    num gpu threads per multiproc:      0
#
# logdet/LU done after  2.6980960369110107 seconds.
# Transferring the covariance matrix to host done after  0.8842713832855225  seconds. sparsity =  0.01765874
# MINRES solve in progress ... 0.9178683757781982 seconds.
# MINRES solve done after  1.1278138160705566 seconds.
# logdet() in progress ...  1.1278648376464844 seconds.
#                                     results
# ==============================================================================
#      inquiries                            error            samples
# --------------------              ---------------------   ---------
# i         parameters       trace    absolute   relative   num   out  converged
# ==============================================================================
# 1               none  -3.722e+04   8.165e+01     0.219%   100     0      False
#
#                                     config
# ==============================================================================
#                 matrix                            stochastic estimator
# -------------------------------------    -------------------------------------
# gram:                           False    method:                           slq
# exponent:                           1    lanczos degree:                    20
# num matrix parameters:              0    lanczos tol:                2.220e-16
# data type:                     64-bit    orthogonalization:               none
#
#              convergence                                 error
# -------------------------------------    -------------------------------------
# min num samples:                   10    abs error tol:              0.000e+00
# max num samples:                  100    rel error tol:                  10.00%
# outlier significance level:     0.00%    confidence level:              95.00%
#
#                                    process
# ==============================================================================
#                  time                                   device
# -------------------------------------    -------------------------------------
# tot wall time (sec):        5.115e-01    num cpu threads:                   16
# alg wall time (sec):        5.105e-01    num gpu devices, multiproc:     0,  0
# cpu proc time (sec):        7.207e+00    num gpu threads per multiproc:      0
#
# logdet/LU done after  1.6404478549957275 seconds.
# Transferring the covariance matrix to host done after  0.9612293243408203  seconds. sparsity =  0.038603
# MINRES solve in progress ... 1.0416371822357178 seconds.
# MINRES solve done after  1.5323853492736816 seconds.
# logdet() in progress ...  1.532435655593872 seconds.
#                                     results
# ==============================================================================
#      inquiries                            error            samples
# --------------------              ---------------------   ---------
# i         parameters       trace    absolute   relative   num   out  converged
# ==============================================================================
# 1               none  -3.807e+04   1.137e+02     0.299%   100     0      False
#
#                                     config
# ==============================================================================
#                 matrix                            stochastic estimator
# -------------------------------------    -------------------------------------
# gram:                           False    method:                           slq
# exponent:                           1    lanczos degree:                    20
# num matrix parameters:              0    lanczos tol:                2.220e-16
# data type:                     64-bit    orthogonalization:               none
#
#              convergence                                 error
# -------------------------------------    -------------------------------------
# min num samples:                   10    abs error tol:              0.000e+00
# max num samples:                  100    rel error tol:                  10.00%
# outlier significance level:     0.00%    confidence level:              95.00%
#
#                                    process
# ==============================================================================
#                  time                                   device
# -------------------------------------    -------------------------------------
# tot wall time (sec):        1.184e+00    num cpu threads:                   16
# alg wall time (sec):        1.182e+00    num gpu devices, multiproc:     0,  0
# cpu proc time (sec):        1.627e+01    num gpu threads per multiproc:      0
#
# logdet/LU done after  2.7226102352142334 seconds.
# Transferring the covariance matrix to host done after  0.9169020652770996  seconds. sparsity =  0.03433108
# MINRES solve in progress ... 0.9852967262268066 seconds.
# MINRES solve done after  1.3955726623535156 seconds.
# logdet() in progress ...  1.3956198692321777 seconds.
#                                     results
# ==============================================================================
#      inquiries                            error            samples
# --------------------              ---------------------   ---------
# i         parameters       trace    absolute   relative   num   out  converged
# ==============================================================================
# 1               none  -3.873e+04   9.729e+01     0.251%   100     0      False
#
#                                     config
# ==============================================================================
#                 matrix                            stochastic estimator
# -------------------------------------    -------------------------------------
# gram:                           False    method:                           slq
# exponent:                           1    lanczos degree:                    20
# num matrix parameters:              0    lanczos tol:                2.220e-16
# data type:                     64-bit    orthogonalization:               none
#
#              convergence                                 error
# -------------------------------------    -------------------------------------
# min num samples:                   10    abs error tol:              0.000e+00
# max num samples:                  100    rel error tol:                  10.00%
# outlier significance level:     0.00%    confidence level:              95.00%
#
#                                    process
# ==============================================================================
#                  time                                   device
# -------------------------------------    -------------------------------------
# tot wall time (sec):        1.047e+00    num cpu threads:                   16
# alg wall time (sec):        1.045e+00    num gpu devices, multiproc:     0,  0
# cpu proc time (sec):        1.426e+01    num gpu threads per multiproc:      0
#
# logdet/LU done after  2.4486100673675537 seconds.
# Transferring the covariance matrix to host done after  0.8979277610778809  seconds. sparsity =  0.025865
# MINRES solve in progress ... 0.9484066963195801 seconds.
# MINRES solve done after  1.2295475006103516 seconds.
# logdet() in progress ...  1.2295966148376465 seconds.
#                                     results
# ==============================================================================
#      inquiries                            error            samples
# --------------------              ---------------------   ---------
# i         parameters       trace    absolute   relative   num   out  converged
# ==============================================================================
# 1               none  -4.193e+04   5.892e+01     0.141%   100     0      False
#
#                                     config
# ==============================================================================
#                 matrix                            stochastic estimator
# -------------------------------------    -------------------------------------
# gram:                           False    method:                           slq
# exponent:                           1    lanczos degree:                    20
# num matrix parameters:              0    lanczos tol:                2.220e-16
# data type:                     64-bit    orthogonalization:               none
#
#              convergence                                 error
# -------------------------------------    -------------------------------------
# min num samples:                   10    abs error tol:              0.000e+00
# max num samples:                  100    rel error tol:                  10.00%
# outlier significance level:     0.00%    confidence level:              95.00%
#
#                                    process
# ==============================================================================
#                  time                                   device
# -------------------------------------    -------------------------------------
# tot wall time (sec):        7.659e-01    num cpu threads:                   16
# alg wall time (sec):        7.647e-01    num gpu devices, multiproc:     0,  0
# cpu proc time (sec):        1.061e+01    num gpu threads per multiproc:      0
#
# logdet/LU done after  1.9966444969177246 seconds.
# Transferring the covariance matrix to host done after  0.8912816047668457  seconds. sparsity =  0.02064312
# MINRES solve in progress ... 0.9321105480194092 seconds.
# MINRES solve done after  1.1463415622711182 seconds.
# logdet() in progress ...  1.1463875770568848 seconds.
#                                     results
# ==============================================================================
#      inquiries                            error            samples
# --------------------              ---------------------   ---------
# i         parameters       trace    absolute   relative   num   out  converged
# ==============================================================================
# 1               none  -4.219e+04   5.534e+01     0.131%   100     0      False
#
#                                     config
# ==============================================================================
#                 matrix                            stochastic estimator
# -------------------------------------    -------------------------------------
# gram:                           False    method:                           slq
# exponent:                           1    lanczos degree:                    20
# num matrix parameters:              0    lanczos tol:                2.220e-16
# data type:                     64-bit    orthogonalization:               none
#
#              convergence                                 error
# -------------------------------------    -------------------------------------
# min num samples:                   10    abs error tol:              0.000e+00
# max num samples:                  100    rel error tol:                  10.00%
# outlier significance level:     0.00%    confidence level:              95.00%
#
#                                    process
# ==============================================================================
#                  time                                   device
# -------------------------------------    -------------------------------------
# tot wall time (sec):        6.013e-01    num cpu threads:                   16
# alg wall time (sec):        6.003e-01    num gpu devices, multiproc:     0,  0
# cpu proc time (sec):        8.349e+00    num gpu threads per multiproc:      0
#
# logdet/LU done after  1.7495043277740479 seconds.
# Transferring the covariance matrix to host done after  0.9036991596221924  seconds. sparsity =  0.01322724
# MINRES solve in progress ... 0.9287021160125732 seconds.
# MINRES solve done after  1.0297212600708008 seconds.
# logdet() in progress ...  1.0297431945800781 seconds.
#                                     results
# ==============================================================================
#      inquiries                            error            samples
# --------------------              ---------------------   ---------
# i         parameters       trace    absolute   relative   num   out  converged
# ==============================================================================
# 1               none  -4.281e+04   4.102e+01     0.096%   100     1      False
#
#                                     config
# ==============================================================================
#                 matrix                            stochastic estimator
# -------------------------------------    -------------------------------------
# gram:                           False    method:                           slq
# exponent:                           1    lanczos degree:                    20
# num matrix parameters:              0    lanczos tol:                2.220e-16
# data type:                     64-bit    orthogonalization:               none
#
#              convergence                                 error
# -------------------------------------    -------------------------------------
# min num samples:                   10    abs error tol:              0.000e+00
# max num samples:                  100    rel error tol:                  10.00%
# outlier significance level:     0.00%    confidence level:              95.00%
#
#                                    process
# ==============================================================================
#                  time                                   device
# -------------------------------------    -------------------------------------
# tot wall time (sec):        4.148e-01    num cpu threads:                   16
# alg wall time (sec):        4.141e-01    num gpu devices, multiproc:     0,  0
# cpu proc time (sec):        5.473e+00    num gpu threads per multiproc:      0
#
# logdet/LU done after  1.4456090927124023 seconds.
# Transferring the covariance matrix to host done after  0.879941463470459  seconds. sparsity =  0.01322724
# MINRES solve in progress ... 0.9045412540435791 seconds.
# MINRES solve done after  1.0021610260009766 seconds.
# logdet() in progress ...  1.0021824836730957 seconds.
#                                     results
# ==============================================================================
#      inquiries                            error            samples
# --------------------              ---------------------   ---------
# i         parameters       trace    absolute   relative   num   out  converged
# ==============================================================================
# 1               none  -4.281e+04   3.971e+01     0.093%   100     0      False
#
#                                     config
# ==============================================================================
#                 matrix                            stochastic estimator
# -------------------------------------    -------------------------------------
# gram:                           False    method:                           slq
# exponent:                           1    lanczos degree:                    20
# num matrix parameters:              0    lanczos tol:                2.220e-16
# data type:                     64-bit    orthogonalization:               none
#
#              convergence                                 error
# -------------------------------------    -------------------------------------
# min num samples:                   10    abs error tol:              0.000e+00
# max num samples:                  100    rel error tol:                  10.00%
# outlier significance level:     0.00%    confidence level:              95.00%
#
#                                    process
# ==============================================================================
#                  time                                   device
# -------------------------------------    -------------------------------------
# tot wall time (sec):        3.911e-01    num cpu threads:                   16
# alg wall time (sec):        3.903e-01    num gpu devices, multiproc:     0,  0
# cpu proc time (sec):        5.403e+00    num gpu threads per multiproc:      0
#
# logdet/LU done after  1.394707441329956 seconds.

# %%
x_pred = np.linspace(0,1,100) ##for big GPs, this is usually not a good idea, but in 1d, we can still do it
                              ##It's better to do predicitons only for a handful of points.

mean1 = my_gp2S.posterior_mean(x_pred.reshape(-1,1))["f(x)"]
var1 =  my_gp2S.posterior_covariance(x_pred.reshape(-1,1), variance_only=False)["v(x)"]

print(my_gp2S.hyperparameters)

plt.figure(figsize = (16,10))
plt.plot(x_pred,mean1, label = "posterior mean", linewidth = 4)
plt.plot(x_pred,f1(x_pred), label = "latent function", linewidth = 4)
plt.fill_between(x_pred, mean1 - 3. * np.sqrt(var1), mean1 + 3. * np.sqrt(var1), alpha = 0.5, color = "grey", label = "var")
plt.scatter(x_data,y_data, color = 'black')
# Out:
# [0.49877437 0.00656977]
