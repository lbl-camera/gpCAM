# %% [markdown]
# # AutonomousExperimenter Basic

# %%
#!pip install gpcam==8.1.10

# %%
from gpcam import AutonomousExperimenterGP
import numpy as np
import time
import sys

# %%
#define an instrument function, this is how the autonomous experimenter interacts with the world.
def instrument(data):
    for entry in data:
        print("I want to know the y_data at: ", entry["x_data"])
        ##always fill in y_data and noise variances
        entry["y_data"] = 0.001 * np.linalg.norm(entry["x_data"])**2
        entry["noise variance"] = 0.01
        print("I received ",entry["y_data"])
        print("")
    return data

# %%
##set up your parameter space
parameters = np.array([[3.0,45.8],
                       [4.0,47.0]])

##set up some hyperparameters, if you have no idea, set them to 1 and make the training bounds large
init_hyperparameters = np.array([ 1.,1.,1.])
hyperparameter_bounds =  np.array([[0.01,100],[0.01,1000.0],[0.01,1000]])

# %%
##let's initialize the autonomous experimenter ...



#...train...
my_ae = AutonomousExperimenterGP(parameters, init_hyperparameters,
                                 hyperparameter_bounds,instrument_function = instrument, online=True, calc_inv=True, 
                                 init_dataset_size=20)
#...train...
my_ae.train(max_iter=2)


print("+++++++++++++++++++++++++++++")
print("+    GO TIME                +")
print("+++++++++++++++++++++++++++++")


#...and run. That's it. You successfully executed an autonomous experiment.
st = time.time()
my_ae.go(N = 100, retrain_globally_at=[], retrain_locally_at=[])
print("Exec time: ", time.time() - st)
# Out:
# I want to know the y_data at:  [27.96977109 27.37100663]
# I received  1.5314800987984556
#
# I want to know the y_data at:  [ 9.82842613 27.44337767]
# I received  0.8497369383558252
#
# I want to know the y_data at:  [30.75123802 11.10110991]
# I received  1.0688732812199135
#
# I want to know the y_data at:  [31.62766978  7.06081911]
# I received  1.0501646622026113
#
# I want to know the y_data at:  [ 3.94366836 35.02993356]
# I received  1.2426487650135978
#
# I want to know the y_data at:  [ 4.83709283 32.06044765]
# I received  1.0512697706974636
#
# I want to know the y_data at:  [22.90238934 33.60538561]
# I received  1.653841379533319
#
# I want to know the y_data at:  [ 7.41902991 43.7911922 ]
# I received  1.972710519291793
#
# I want to know the y_data at:  [21.61061395 42.35456473]
# I received  2.2609277890174124
#
# I want to know the y_data at:  [38.27702438 12.44149161]
# I received  1.619921308737595
#
# I want to know the y_data at:  [40.33478    18.86445594]
# I received  1.982762175308897
#
# I want to know the y_data at:  [25.15984981  4.78741461]
# I received  0.655937381186377
#
# I want to know the y_data at:  [ 5.97364885 21.84455041]
# I received  0.5128688629411255
#
# I want to know the y_data at:  [41.79731651 15.77256292]
# I received  1.9957894083491599
#
# I want to know the y_data at:  [31.75541659 15.02792282]
# I received  1.2342449473351218
#
# I want to know the y_data at:  [45.01409777 35.79900968]
# I received  3.3078380918208095
#
# I want to know the y_data at:  [28.568134   14.54537716]
# I received  1.027706276685489
#
# I want to know the y_data at:  [11.47331455 37.28923056]
# I received  1.5221236626452914
#
# I want to know the y_data at:  [22.38661822 43.67087051]
# I received  2.4083056063207615
#
# I want to know the y_data at:  [10.25891812 10.26707998]
# I received  0.21065833249644722
#
# +++++++++++++++++++++++++++++
# +    GO TIME                +
# +++++++++++++++++++++++++++++
# I want to know the y_data at:  [3.02418387 4.05289774]
# I received  0.02557166811149898
#
# I want to know the y_data at:  [45.61090719 46.99775741]
# I received  4.2891440556555
#
# I want to know the y_data at:  [45.78839334  4.01441347]
# I received  2.112692480160983
#
# I want to know the y_data at:  [ 3.10449789 46.97310415]
# I received  2.216110421062574
#
# I want to know the y_data at:  [33.54628817 46.99974227]
# I received  3.3343292232741373
#
# I want to know the y_data at:  [45.79806099 26.42598552]
# I received  2.7957951014194515
#
# I want to know the y_data at:  [15.73422216  4.00309318]
# I received  0.26359050192011335
#
# I want to know the y_data at:  [ 3.00580415 15.06741873]
# I received  0.23606196590768896
#
# I want to know the y_data at:  [45.7349777  46.94435263]
# I received  4.295460429544942
#
# I want to know the y_data at:  [35.43101327 36.10632192]
# I received  2.559023183769031
#
# I want to know the y_data at:  [17.94263127 19.11770294]
# I received  0.6874245823618919
#
# I want to know the y_data at:  [15.52381203 46.99014547]
# I received  2.449062510933603
#
# I want to know the y_data at:  [45.79612413  4.03622322]
# I received  2.113576082817946
#
# I want to know the y_data at:  [3.13674214 4.08832311]
# I received  0.026553537132596977
#
# I want to know the y_data at:  [35.43581715  4.00632136]
# I received  1.2717477477539345
#
# I want to know the y_data at:  [45.79999104 30.71855506]
# I received  3.0412688045505107
#
# I want to know the y_data at:  [29.05734712 46.9978221 ]
# I received  3.053124703904078
#
# I want to know the y_data at:  [ 3.00092015 24.51423204]
# I received  0.6099530941425769
#
# I want to know the y_data at:  [45.79329327 14.60084175]
# I received  2.3102102881572595
#
# I want to know the y_data at:  [ 3.17491814 46.9554868 ]
# I received  2.2148978454045576
#
# I want to know the y_data at:  [34.9598632  27.09740086]
# I received  1.9564611680832034
#
# I want to know the y_data at:  [19.83277715  4.0034269 ]
# I received  0.4093664763127076
#
# I want to know the y_data at:  [18.68565302 25.9686255 ]
# I received  1.0235231395514952
#
# I want to know the y_data at:  [45.7982208  40.05358017]
# I received  3.7017663131457303
#
# I want to know the y_data at:  [16.48623753 13.53596457]
# I received  0.45501836463588907
#
# I want to know the y_data at:  [34.58152031 39.99368899]
# I received  2.7953767058896757
#
# I want to know the y_data at:  [3.08730695 4.07007549]
# I received  0.026096978714149177
#
# I want to know the y_data at:  [ 3.00405509 15.06103147]
# I received  0.2358590159446911
#
# I want to know the y_data at:  [ 3.00059435 38.81897132]
# I received  1.5159161005177666
#
# I want to know the y_data at:  [45.70652784  4.01910793]
# I received  2.105239915347771
#
# I want to know the y_data at:  [45.79745102 21.63134544]
# I received  2.5653216256323583
#
# I want to know the y_data at:  [13.92499955 46.99891934]
# I received  2.4028040310261574
#
# I want to know the y_data at:  [16.66642493 33.77585752]
# I received  1.4185782711791741
#
# I want to know the y_data at:  [45.76825352 46.85832423]
# I received  4.290435580270549
#
# I want to know the y_data at:  [26.67417058 21.71699292]
# I received  1.1831391578438666
#
# I want to know the y_data at:  [36.94332567 46.98951741]
# I received  3.5728240584662263
#
# I want to know the y_data at:  [29.88117854  4.00385481]
# I received  0.9089156844030885
#
# I want to know the y_data at:  [ 3.17014487 46.38088534]
# I received  2.161236343748712
#
# I want to know the y_data at:  [29.00799044 35.18956317]
# I received  2.0797688654445805
#
# I want to know the y_data at:  [11.73345724  4.00584425]
# I received  0.15372080705347868
#
# I want to know the y_data at:  [12.28991129 18.5302764 ]
# I received  0.49441306298436083
#
# I want to know the y_data at:  [ 3.00600743 28.02811563]
# I received  0.7946113466053036
#
# I want to know the y_data at:  [24.11302718 46.97915648]
# I received  2.788479222915432
#
# I want to know the y_data at:  [37.96413089 29.4797794 ]
# I received  2.310332627515053
#
# I want to know the y_data at:  [45.78998913 11.40908602]
# I received  2.2268903487637446
#
# I want to know the y_data at:  [21.72692874 11.99411061]
# I received  0.6159181217060623
#
# I want to know the y_data at:  [38.0957674   4.00001221]
# I received  1.4672875914615222
#
# I want to know the y_data at:  [ 3.08400711 10.81962615]
# I received  0.12657540980203708
#
# I want to know the y_data at:  [45.79555853 36.91966569]
# I received  3.460294894970838
#
# I want to know the y_data at:  [34.11033064 22.01322985]
# I received  1.6480969448207725
#
# I want to know the y_data at:  [14.89247906 39.05256211]
# I received  1.7468885395700324
#
# I want to know the y_data at:  [45.79634801 20.91157656]
# I received  2.5345995257894205
#
# I want to know the y_data at:  [ 3.01191234 38.09455994]
# I received  1.4602671127149784
#
# I want to know the y_data at:  [ 3.02507965 20.4274087 ]
# I received  0.42643013300329025
#
# I want to know the y_data at:  [15.23690461 27.41996018]
# I received  0.98401747830498
#
# I want to know the y_data at:  [11.99782413 46.99615795]
# I received  2.352586646256158
#
# I want to know the y_data at:  [38.49077597 40.80622947]
# I received  3.146688198335762
#
# I want to know the y_data at:  [45.6947406 46.8367814]
# I received  4.28169341047201
#
# I want to know the y_data at:  [22.09735963  4.01667681]
# I received  0.5044269953570817
#
# I want to know the y_data at:  [45.73902837 29.61652055]
# I received  2.969197005265212
#
# I want to know the y_data at:  [22.79951869 20.40160703]
# I received  0.9360436218695644
#
# I want to know the y_data at:  [ 3.37095976 46.97306563]
# I received  2.217832264286412
#
# I want to know the y_data at:  [27.40479941 46.9913732 ]
# I received  2.959212186421676
#
# I want to know the y_data at:  [26.12513286 37.72457414]
# I received  2.1056660609805493
#
# I want to know the y_data at:  [9.96902497 4.00657119]
# I received  0.11543407166109487
#
# I want to know the y_data at:  [11.79568954 12.88635886]
# I received  0.30519653641738786
#
# I want to know the y_data at:  [24.29623737 28.99149468]
# I received  1.4308139142127565
#
# I want to know the y_data at:  [45.66028657  4.05853038]
# I received  2.1013334381981768
#
# I want to know the y_data at:  [37.60507541 46.99833444]
# I received  3.622985136352379
#
# I want to know the y_data at:  [ 3.00612498 30.6285966 ]
# I received  0.9471477169978684
#
# I want to know the y_data at:  [35.13761767 32.06228958]
# I received  2.2626425886778696
#
# I want to know the y_data at:  [12.39763533 32.27957449]
# I received  1.1956722909752082
#
# I want to know the y_data at:  [45.79419189 12.50472223]
# I received  2.253476088991811
#
# I want to know the y_data at:  [34.20861506  4.00472644]
# I received  1.1862671784257686
#
# I want to know the y_data at:  [19.4715915  46.99247268]
# I received  2.5874353642313737
#
# I want to know the y_data at:  [12.51309453 22.2594843 ]
# I received  0.6520621758549043
#
# I want to know the y_data at:  [ 3.00372701 10.00763834]
# I received  0.1091752010511554
#
# I want to know the y_data at:  [36.92466318 22.36882876]
# I received  1.8637952508063866
#
# I want to know the y_data at:  [20.56025236 10.66592715]
# I received  0.5364859792639936
#
# I want to know the y_data at:  [3.31668967 4.07158749]
# I received  0.027578255072747613
#
# Exec time:  3.2399420738220215
