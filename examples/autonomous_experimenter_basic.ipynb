# %% [markdown]
# # AutonomousExperimenter Basic

# %%
#!pip install gpcam==8.1.0

# %%
from gpcam import AutonomousExperimenterGP
import numpy as np

def instrument(data):
    for entry in data:
        print("I want to know the y_data at: ", entry["x_data"])
        entry["y_data"] = np.sin(np.linalg.norm(entry["x_data"]))
        print("I received ",entry["y_data"])
        print("")
    return data

##set up your parameter space
parameters = np.array([[3.0,45.8],
                       [4.0,47.0]])

##set up some hyperparameters, if you have no idea, set them to 1 and make the training bounds large
init_hyperparameters = np.array([1,1,1])
hyperparameter_bounds =  np.array([[0.01,100],[0.01,100.0],[0.01,100]])

##let's initialize the autonomous experimenter ...
my_ae = AutonomousExperimenterGP(parameters, init_hyperparameters, 
                                 hyperparameter_bounds,instrument_function = instrument,online=False, 
                                 init_dataset_size=10, info=True)
#...train...
my_ae.train()

#...and run. That's it. You successfully executed an autonomous experiment.
my_ae.go(N = 100)
# Out:
# I want to know the y_data at:  [32.22303652  9.66899592]
# I received  0.7926127265800262
#
# I want to know the y_data at:  [19.82379546 29.78737501]
# I received  -0.9402451855079661
#
# I want to know the y_data at:  [24.9406817  13.23388815]
# I received  0.040063835429074525
#
# I want to know the y_data at:  [30.587386   12.78634227]
# I received  0.9863141068664529
#
# I want to know the y_data at:  [14.84452201 21.80728343]
# I received  0.9481952584801617
#
# I want to know the y_data at:  [ 7.77743924 21.18991187]
# I received  -0.548842256609569
#
# I want to know the y_data at:  [29.59750177 39.52262185]
# I received  -0.7763607114011644
#
# I want to know the y_data at:  [37.04380753 10.15550645]
# I received  0.6529990252234718
#
# I want to know the y_data at:  [ 8.34082095 16.83936007]
# I received  -0.05768146171635089
#
# I want to know the y_data at:  [32.79696677 37.11022502]
# I received  -0.6740163581920502
#
# 2024-06-12 12:27:50.448 | INFO     | fvgp.gp:train:491 - objective function: <bound method GPMarginalDensity.neg_log_likelihood of <fvgp.gp_marginal_density.GPMarginalDensity object at 0x7f1a2501c7c0>>
# 2024-06-12 12:27:50.449 | INFO     | fvgp.gp:train:492 - method: global
# 2024-06-12 12:27:50.450 | INFO     | fvgp.gp_training:_optimize_log_likelihood:301 - fvGP is performing a global differential evolution algorithm to find the optimal hyperparameters.
# 2024-06-12 12:27:50.451 | INFO     | fvgp.gp_training:_optimize_log_likelihood:305 - bounds: [[1.e-02 1.e+02]
#  [1.e-02 1.e+02]
#  [1.e-02 1.e+02]]
# differential_evolution step 1: f(x)= 14.1366972002829
# differential_evolution step 2: f(x)= 14.1366972002829
# differential_evolution step 3: f(x)= 14.009292272916205
# differential_evolution step 4: f(x)= 13.43602839258419
# differential_evolution step 5: f(x)= 11.638993975882407
# differential_evolution step 6: f(x)= 10.36942048571417
# differential_evolution step 7: f(x)= 10.110008213334067
# differential_evolution step 8: f(x)= 10.110008213334067
# differential_evolution step 9: f(x)= 10.110008213334067
# differential_evolution step 10: f(x)= 10.110008213334067
# differential_evolution step 11: f(x)= 10.110008213334067
# differential_evolution step 12: f(x)= 10.021726154469892
# differential_evolution step 13: f(x)= 10.021726154469892
# differential_evolution step 14: f(x)= 9.61157856413423
# differential_evolution step 15: f(x)= 9.61157856413423
# differential_evolution step 16: f(x)= 9.580066519513414
# differential_evolution step 17: f(x)= 9.580066519513414
# differential_evolution step 18: f(x)= 9.580066519513414
# differential_evolution step 19: f(x)= 9.568032389485957
# differential_evolution step 20: f(x)= 9.568032389485957
# 2024-06-12 12:27:50.620 | INFO     | fvgp.gp_training:_optimize_log_likelihood:319 - fvGP found hyperparameters [0.46923316 3.92364508 6.3350343 ] with objective function eval 9.568032389485957             via global optimization
# /home/marcus/VirtualEnvironments/gpcam_dev/lib/python3.10/site-packages/fvgp/gp.py:278: UserWarning: No noise function or measurement noise provided. Noise variances will be set to 1% of mean(y_data).
#   self.likelihood = GPlikelihood(self.data.x_data,
# /home/marcus/VirtualEnvironments/gpcam_dev/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:487: UserWarning: differential_evolution: the 'vectorized' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# I want to know the y_data at:  [ 3.03148786 46.96101634]
# I received  0.06508289830997621
#
# I want to know the y_data at:  [45.72814583 39.83144446]
# I received  -0.8151676626795442
#
# I want to know the y_data at:  [17.53853793 46.50943247]
# I received  -0.5303964663910258
#
# I want to know the y_data at:  [45.58860038 21.79781303]
# I received  0.26320279295556664
#
# I want to know the y_data at:  [15.82460873  4.39036585]
# I received  -0.6551536284326954
#
# I want to know the y_data at:  [4.02227992 4.58078772]
# I received  -0.186002568911406
#
# I want to know the y_data at:  [ 9.92703754 35.93718846]
# I received  -0.40413968380051235
#
# I want to know the y_data at:  [44.22009385  4.50897132]
# I received  0.45028493055194896
#
# I want to know the y_data at:  [36.74087409 24.45437082]
# I received  0.1522204420356362
#
# I want to know the y_data at:  [27.86789745 26.64203309]
# I received  0.7545547084095893
#
# I want to know the y_data at:  [38.52721984 46.93663969]
# I received  -0.8591787567907598
#
# 2024-06-12 12:27:51.023 | INFO     | fvgp.gp:train:491 - objective function: <bound method GPMarginalDensity.neg_log_likelihood of <fvgp.gp_marginal_density.GPMarginalDensity object at 0x7f1a2501c7c0>>
# 2024-06-12 12:27:51.025 | INFO     | fvgp.gp:train:492 - method: global
# 2024-06-12 12:27:51.026 | INFO     | fvgp.gp_training:_optimize_log_likelihood:301 - fvGP is performing a global differential evolution algorithm to find the optimal hyperparameters.
# 2024-06-12 12:27:51.027 | INFO     | fvgp.gp_training:_optimize_log_likelihood:305 - bounds: [[1.e-02 1.e+02]
#  [1.e-02 1.e+02]
#  [1.e-02 1.e+02]]
# differential_evolution step 1: f(x)= 31.609858595112108
# differential_evolution step 2: f(x)= 29.714489181068345
# differential_evolution step 3: f(x)= 27.194177216564906
# differential_evolution step 4: f(x)= 27.194177216564906
# differential_evolution step 5: f(x)= 26.5019551474685
# differential_evolution step 6: f(x)= 26.5019551474685
# differential_evolution step 7: f(x)= 26.5019551474685
# differential_evolution step 8: f(x)= 26.117608649817456
# differential_evolution step 9: f(x)= 26.117608649817456
# differential_evolution step 10: f(x)= 26.117608649817456
# differential_evolution step 11: f(x)= 26.01851702584774
# differential_evolution step 12: f(x)= 23.225318758414847
# differential_evolution step 13: f(x)= 22.555428249994037
# differential_evolution step 14: f(x)= 22.13167205288252
# differential_evolution step 15: f(x)= 19.900367354758536
# differential_evolution step 16: f(x)= 19.900367354758536
# differential_evolution step 17: f(x)= 18.715233212465733
# differential_evolution step 18: f(x)= 18.715233212465733
# differential_evolution step 19: f(x)= 18.715233212465733
# differential_evolution step 20: f(x)= 18.715233212465733
# 2024-06-12 12:27:51.209 | INFO     | fvgp.gp_training:_optimize_log_likelihood:319 - fvGP found hyperparameters [0.25866807 5.00816744 5.6221047 ] with objective function eval 18.715233212465733             via global optimization
# I want to know the y_data at:  [ 3.29311095 30.38148116]
# I received  -0.7555498178318882
#
# I want to know the y_data at:  [45.7891527  31.05790509]
# I received  -0.9391661161120859
#
# I want to know the y_data at:  [25.38185718  4.03016473]
# I received  0.537172888767249
#
# I want to know the y_data at:  [26.21324459 46.87284354]
# I received  -0.2932757236967679
#
# I want to know the y_data at:  [20.46781729 38.39516142]
# I received  -0.454934533459527
#
# I want to know the y_data at:  [45.78707815 13.10715759]
# I received  -0.4814440898231699
#
# I want to know the y_data at:  [16.57686075 13.05763037]
# I received  0.7765412570627428
#
# I want to know the y_data at:  [10.26578212 46.99986095]
# I received  -0.8327426959273536
#
# I want to know the y_data at:  [ 3.01265397 38.75893179]
# I received  0.9233544515868647
#
# I want to know the y_data at:  [45.69609611 46.99180118]
# I received  0.41396128611981015
#
# I want to know the y_data at:  [39.06310277 33.47697711]
# I received  0.9245924209785715
#
# I want to know the y_data at:  [ 3.03101317 13.10601971]
# I received  0.7742778892030122
#
# I want to know the y_data at:  [22.37371012 20.73867625]
# I received  -0.7888590735742714
#
# I want to know the y_data at:  [11.74462112 28.78569903]
# I received  -0.32072759563510655
#
# I want to know the y_data at:  [35.34243208  4.08397467]
# I received  -0.8521556998665897
#
# I want to know the y_data at:  [38.67152014 17.39754378]
# I received  -0.9999770679634753
#
# I want to know the y_data at:  [9.91820828 8.389606  ]
# I received  0.4116416105420438
#
# I want to know the y_data at:  [30.89386591 20.05671526]
# I received  -0.7615266912986228
#
# I want to know the y_data at:  [32.39998527 46.99492767]
# I received  0.5078590108259086
#
# I want to know the y_data at:  [26.02004736 33.60194359]
# I received  -0.9962067302514547
#
# 2024-06-12 12:27:52.742 | INFO     | fvgp.gp:train:491 - objective function: <bound method GPMarginalDensity.neg_log_likelihood of <fvgp.gp_marginal_density.GPMarginalDensity object at 0x7f1a2501c7c0>>
# 2024-06-12 12:27:52.743 | INFO     | fvgp.gp:train:492 - method: local
# 2024-06-12 12:27:52.745 | INFO     | fvgp.gp_training:_optimize_log_likelihood:325 - fvGP is performing a local update of the hyper parameters.
# 2024-06-12 12:27:52.748 | INFO     | fvgp.gp_training:_optimize_log_likelihood:330 - bounds: [[1.e-02 1.e+02]
#  [1.e-02 1.e+02]
#  [1.e-02 1.e+02]]
# /home/marcus/VirtualEnvironments/gpcam_dev/lib/python3.10/site-packages/fvgp/gp_training.py:331: RuntimeWarning: Method L-BFGS-B does not use Hessian information (hess).
#   OptimumEvaluation = minimize(
# I want to know the y_data at:  [20.63598518  4.00584182]
# I received  0.8248592806587429
#
# I want to know the y_data at:  [14.80412273 38.20720341]
# I received  -0.133914163783579
#
# I want to know the y_data at:  [42.40521898 46.93310216]
# I received  0.40863909460546405
#
# I want to know the y_data at:  [ 6.58859022 46.90120027]
# I received  -0.23559021284730935
#
# I want to know the y_data at:  [40.24302275  4.06973591]
# I received  0.38242658724197814
#
# I want to know the y_data at:  [42.13998665 24.92426857]
# I received  -0.9652347286096435
#
# I want to know the y_data at:  [29.66162064  4.01194505]
# I received  -0.9962540524884917
#
# I want to know the y_data at:  [12.56232679 14.14842688]
# I received  0.07100892989955097
#
# I want to know the y_data at:  [42.41715779 12.89128949]
# I received  0.3434068144162175
#
# I want to know the y_data at:  [22.16451604 46.99277865]
# I received  0.9926556368976766
#
# 2024-06-12 12:27:53.699 | INFO     | fvgp.gp:train:491 - objective function: <bound method GPMarginalDensity.neg_log_likelihood of <fvgp.gp_marginal_density.GPMarginalDensity object at 0x7f1a2501c7c0>>
# 2024-06-12 12:27:53.701 | INFO     | fvgp.gp:train:492 - method: global
# 2024-06-12 12:27:53.702 | INFO     | fvgp.gp_training:_optimize_log_likelihood:301 - fvGP is performing a global differential evolution algorithm to find the optimal hyperparameters.
# 2024-06-12 12:27:53.703 | INFO     | fvgp.gp_training:_optimize_log_likelihood:305 - bounds: [[1.e-02 1.e+02]
#  [1.e-02 1.e+02]
#  [1.e-02 1.e+02]]
# differential_evolution step 1: f(x)= 87.44879348158483
# differential_evolution step 2: f(x)= 87.0687566165114
# differential_evolution step 3: f(x)= 86.34778040517432
# differential_evolution step 4: f(x)= 83.4209720292477
# differential_evolution step 5: f(x)= 77.19034128647456
# differential_evolution step 6: f(x)= 77.19034128647456
# differential_evolution step 7: f(x)= 69.1370961021822
# differential_evolution step 8: f(x)= 69.1370961021822
# differential_evolution step 9: f(x)= 57.68286017371956
# differential_evolution step 10: f(x)= 53.2470298947196
# differential_evolution step 11: f(x)= 53.2470298947196
# differential_evolution step 12: f(x)= 53.2470298947196
# differential_evolution step 13: f(x)= 53.2470298947196
# differential_evolution step 14: f(x)= 53.2470298947196
# differential_evolution step 15: f(x)= 53.2470298947196
# differential_evolution step 16: f(x)= 53.2470298947196
# differential_evolution step 17: f(x)= 53.2470298947196
# differential_evolution step 18: f(x)= 53.2470298947196
# differential_evolution step 19: f(x)= 53.2470298947196
# differential_evolution step 20: f(x)= 53.2470298947196
# 2024-06-12 12:27:53.923 | INFO     | fvgp.gp_training:_optimize_log_likelihood:319 - fvGP found hyperparameters [0.34068314 2.7117936  2.11585787] with objective function eval 53.2470298947196             via global optimization
# I want to know the y_data at:  [32.68624214 30.94409338]
# I received  0.85627045526958
#
# I want to know the y_data at:  [38.07973312 40.94097564]
# I received  -0.5939596716395352
#
# I want to know the y_data at:  [ 3.17401909 25.02412095]
# I received  0.09174111780932065
#
# I want to know the y_data at:  [21.6010387   8.96842717]
# I received  -0.9850536996904674
#
# I want to know the y_data at:  [19.60740804 25.1158394 ]
# I received  0.43240022196805666
#
# I want to know the y_data at:  [ 9.30340055 42.07011579]
# I received  -0.7806971511441196
#
# I want to know the y_data at:  [14.62278582 32.84225955]
# I received  -0.9842359435695083
#
# I want to know the y_data at:  [24.16899543 42.33618642]
# I received  -0.9985097215824559
#
# I want to know the y_data at:  [18.93917005 16.94484395]
# I received  0.2765916568407734
#
# I want to know the y_data at:  [ 3.13290759 18.52871974]
# I received  -0.05780834473258471
#
# 2024-06-12 12:27:54.382 | INFO     | fvgp.gp:train:491 - objective function: <bound method GPMarginalDensity.neg_log_likelihood of <fvgp.gp_marginal_density.GPMarginalDensity object at 0x7f1a2501c7c0>>
# 2024-06-12 12:27:54.383 | INFO     | fvgp.gp:train:492 - method: local
# 2024-06-12 12:27:54.384 | INFO     | fvgp.gp_training:_optimize_log_likelihood:325 - fvGP is performing a local update of the hyper parameters.
# 2024-06-12 12:27:54.385 | INFO     | fvgp.gp_training:_optimize_log_likelihood:330 - bounds: [[1.e-02 1.e+02]
#  [1.e-02 1.e+02]
#  [1.e-02 1.e+02]]
# I want to know the y_data at:  [45.78555949 44.09354902]
# I received  0.6694994348389415
#
# I want to know the y_data at:  [45.79819318  7.57883293]
# I received  0.6463926407928006
#
# I want to know the y_data at:  [45.78501906 28.21324897]
# I received  -0.3640549982965691
#
# I want to know the y_data at:  [ 3.3618442  44.33797147]
# I received  0.46438887831860676
#
# I want to know the y_data at:  [ 3.05743701 10.46703962]
# I received  -0.9958502600902105
#
# I want to know the y_data at:  [45.78978154 15.45812541]
# I received  -0.9337509096461322
#
# I want to know the y_data at:  [45.79600987 35.66624502]
# I received  0.997313740588053
#
# I want to know the y_data at:  [24.87653611  6.53284047]
# I received  0.5541078901992473
#
# I want to know the y_data at:  [ 3.02732287 33.5914197 ]
# I received  0.7379052508375624
#
# I want to know the y_data at:  [ 3.0107112  26.99590197]
# I received  0.8961723243096004
#
# I want to know the y_data at:  [45.79264347 18.98639642]
# I received  -0.6387050472757475
#
# I want to know the y_data at:  [26.05726148 44.5000276 ]
# I received  0.9641635384553661
#
# I want to know the y_data at:  [3.01038714 6.64397303]
# I received  0.8473512362472211
#
# I want to know the y_data at:  [ 3.08819788 22.97967098]
# I received  -0.9302533117845994
#
# I want to know the y_data at:  [ 3.17909741 40.60800521]
# I received  0.10823520244369003
#
# I want to know the y_data at:  [29.66117324 15.25214892]
# I received  0.9337173953049643
#
# I want to know the y_data at:  [45.75272379 37.79229603]
# I received  0.34049950534534323
#
# I want to know the y_data at:  [19.36319272 11.04773393]
# I received  -0.2974556404078045
#
# I want to know the y_data at:  [ 3.16704676 15.34832389]
# I received  0.03628559007451295
#
# I want to know the y_data at:  [19.42481455 18.85051503]
# I received  0.9343898024749304
#
# 2024-06-12 12:27:56.229 | INFO     | fvgp.gp:train:491 - objective function: <bound method GPMarginalDensity.neg_log_likelihood of <fvgp.gp_marginal_density.GPMarginalDensity object at 0x7f1a2501c7c0>>
# 2024-06-12 12:27:56.230 | INFO     | fvgp.gp:train:492 - method: local
# 2024-06-12 12:27:56.231 | INFO     | fvgp.gp_training:_optimize_log_likelihood:325 - fvGP is performing a local update of the hyper parameters.
# 2024-06-12 12:27:56.232 | INFO     | fvgp.gp_training:_optimize_log_likelihood:330 - bounds: [[1.e-02 1.e+02]
#  [1.e-02 1.e+02]
#  [1.e-02 1.e+02]]
# I want to know the y_data at:  [35.38904486 46.9806239 ]
# I received  0.7657496006398375
#
# I want to know the y_data at:  [7.02628255 4.05832715]
# I received  0.9663587978627989
#
# I want to know the y_data at:  [13.12861778 46.98807264]
# I received  -0.99567741948619
#
# I want to know the y_data at:  [12.88099296  4.01929106]
# I received  0.7999035594034996
#
# I want to know the y_data at:  [34.43454452 19.086278  ]
# I received  0.9949607166404798
#
# I want to know the y_data at:  [ 5.77636948 31.13425627]
# I received  0.24705901575946987
#
# I want to know the y_data at:  [17.26790954 31.3857483 ]
# I received  -0.95357816295085
#
# I want to know the y_data at:  [43.73802331 35.62558856]
# I received  -0.13726560590658715
#
# I want to know the y_data at:  [27.59122118  4.01139384]
# I received  0.3829947653636842
#
# I want to know the y_data at:  [28.3876509  46.98521059]
# I received  -0.9965739402297324
#
# I want to know the y_data at:  [ 5.63538556 15.41670107]
# I received  -0.6491207827067742
#
# I want to know the y_data at:  [35.07552164 33.71896452]
# I received  -0.9991928180452193
#
# I want to know the y_data at:  [40.86720902 40.20751157]
# I received  0.7044974266477153
#
# I want to know the y_data at:  [19.41273752 46.98863775]
# I received  0.5440972096634775
#
# I want to know the y_data at:  [23.86570326 29.24768662]
# I received  0.05002573115245544
#
# I want to know the y_data at:  [15.4165652  46.93256761]
# I received  -0.7615630474310551
#
# I want to know the y_data at:  [17.98317763  4.12652581]
# I received  -0.3885001019020867
#
# I want to know the y_data at:  [23.1236589   4.03430039]
# I received  -0.9960421855499859
#
# I want to know the y_data at:  [38.00238584  4.19433719]
# I received  0.5090137530475759
