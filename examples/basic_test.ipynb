# %%
#!pip install gpcam==8.0.0

# %%
from gpcam.autonomous_experimenter import AutonomousExperimenterGP
import numpy as np

def instrument(data):
    for entry in data:
        print("I want to know the y_data at: ", entry["x_data"])
        entry["y_data"] = np.sin(np.linalg.norm(entry["x_data"]))
        print("I received ",entry["y_data"])
        print("")
    return data

##set up your parameter space
parameters = np.array([[3.0,45.8],
                       [4.0,47.0]])

##set up some hyperparameters, if you have no idea, set them to 1 and make the training bounds large
init_hyperparameters = np.array([1,1,1])
hyperparameter_bounds =  np.array([[0.01,100],[0.01,100.0],[0.01,100]])

##let's initialize the autonomous experimenter ...
my_ae = AutonomousExperimenterGP(parameters, init_hyperparameters,
                                 hyperparameter_bounds,instrument_func = instrument,  
                                 init_dataset_size=10, info=False)
#...train...
my_ae.train()

#...and run. That's it. You successfully executed an autonomous experiment.
my_ae.go(N = 100)
# Out:
# I want to know the y_data at:  [23.13194374 12.00680524]
# I received  0.8014331007846598
#
# I want to know the y_data at:  [ 8.80612593 45.37724232]
# I received  0.7833673442813909
#
# I want to know the y_data at:  [41.42657762 23.09495143]
# I received  -0.30068056189162345
#
# I want to know the y_data at:  [38.75619928 28.07415087]
# I received  -0.6684732010137782
#
# I want to know the y_data at:  [33.526373   18.76738198]
# I received  0.6613798122546398
#
# I want to know the y_data at:  [26.75158458 37.83716502]
# I received  0.7067822370299519
#
# I want to know the y_data at:  [ 7.0970342  36.80405008]
# I received  -0.21533627389573207
#
# I want to know the y_data at:  [39.94089579 42.42455938]
# I received  0.9890413579240317
#
# I want to know the y_data at:  [35.43430512 23.60809284]
# I received  -0.9860814469360434
#
# I want to know the y_data at:  [35.3926039   4.69123456]
# I received  -0.9105608919288894
#
# I want to know the y_data at:  [ 3.00106819 27.25017401]
# I received  0.7574534188107204
#
# I want to know the y_data at:  [3.09722274 5.01060863]
# I received  -0.3825924932072008
#
# I want to know the y_data at:  [ 3.11561523 19.04344844]
# I received  0.4323303768261114
#
# I want to know the y_data at:  [45.73172722 34.01285803]
# I received  0.4303566847731992
#
# I want to know the y_data at:  [45.65787826 11.86935692]
# I received  -0.05154156673598501
#
# I want to know the y_data at:  [18.99399188 31.521229  ]
# I received  -0.7817622122799197
#
# I want to know the y_data at:  [45.12429592 46.93984348]
# I received  0.7588928193545167
#
# I want to know the y_data at:  [ 3.08452329 11.82531256]
# I received  -0.3385662132169054
#
# I want to know the y_data at:  [14.89269288 23.03741648]
# I received  0.7461960145629806
#
# I want to know the y_data at:  [ 3.90466303 41.04496977]
# I received  -0.37979517776278043
#
# I want to know the y_data at:  [26.60838917 46.96317711]
# I received  -0.539801590889995
#
# I want to know the y_data at:  [24.65416159  5.69436648]
# I received  0.1696649267570412
#
# I want to know the y_data at:  [13.53268347  7.64704518]
# I received  0.16339189174266758
#
# I want to know the y_data at:  [18.04115102 41.5609682 ]
# I received  0.9700673493022378
#
# I want to know the y_data at:  [12.4864283 15.2697373]
# I received  0.7678304162469726
#
# I want to know the y_data at:  [25.97971981 26.32924373]
# I received  -0.6520334189567961
#
# I want to know the y_data at:  [34.67796929 12.38419219]
# I received  -0.7682866494901853
#
# I want to know the y_data at:  [45.19611357  5.02050293]
# I received  0.9968819500850389
#
# I want to know the y_data at:  [32.61880545 32.71151894]
# I received  0.800619177364977
#
# I want to know the y_data at:  [22.65452756 19.3692714 ]
# I received  -0.9992336296804488
#
# I want to know the y_data at:  [ 9.56469647 30.95573738]
# I received  0.8325979291560299
#
# I want to know the y_data at:  [36.32392151 37.63066134]
# I received  0.8935204900225722
#
# I want to know the y_data at:  [44.59595877 17.63788956]
# I received  -0.7401728971867589
#
# I want to know the y_data at:  [16.37201186 46.85096618]
# I received  -0.594223172154319
#
# I want to know the y_data at:  [35.55342575 46.61555658]
# I received  0.8742303447761721
#
# I want to know the y_data at:  [16.18949551 36.24172149]
# I received  0.9116795369406516
#
# I want to know the y_data at:  [ 6.42638099 22.79570096]
# I received  -0.9925335090219988
#
# I want to know the y_data at:  [30.33468236 42.32910168]
# I received  0.9713220171554074
#
# I want to know the y_data at:  [44.11994279 38.60694184]
# I received  0.874192611355086
#
# I want to know the y_data at:  [45.48909519 27.04985198]
# I received  0.4644837028518684
#
# I want to know the y_data at:  [39.55264534  8.67691694]
# I received  0.34053634290716894
#
# I want to know the y_data at:  [18.51692821  4.59771842]
# I received  0.22762514832284858
#
# I want to know the y_data at:  [29.30458885  9.76670531]
# I received  -0.5026393300842025
#
# I want to know the y_data at:  [19.49720593 25.92704995]
# I received  0.854227713363647
#
# I want to know the y_data at:  [28.70701879 15.90117273]
# I received  0.9855922994587811
#
# I want to know the y_data at:  [26.32264906 32.34305732]
# I received  -0.7578930564348983
#
# I want to know the y_data at:  [28.48191006 22.04370713]
# I received  -0.9936867373165779
#
# I want to know the y_data at:  [11.62168127 40.51461819]
# I received  -0.9656194491222709
#
# I want to know the y_data at:  [ 3.38079589 32.59059493]
# I received  0.975625395316605
#
# I want to know the y_data at:  [17.78150823 13.27807895]
# I received  -0.1996042023420156
#
# I want to know the y_data at:  [39.50649076 33.6815901 ]
# I received  0.9968688338368078
#
# I want to know the y_data at:  [10.66251191 26.60009714]
# I received  -0.37389158637444725
#
# I want to know the y_data at:  [39.23284759 15.8105038 ]
# I received  -0.993655820310388
#
# I want to know the y_data at:  [9.7852278  4.03651633]
# I received  -0.9169279933451351
#
# I want to know the y_data at:  [ 8.35242706 10.52200209]
# I received  0.7628753989773542
#
# I want to know the y_data at:  [31.90840098 28.02797775]
# I received  -0.9982806651030182
#
# I want to know the y_data at:  [23.41363082 42.67846893]
# I received  -0.9998777436907006
#
# I want to know the y_data at:  [ 6.78921923 15.92935731]
# I received  -0.9993130210163056
#
# I want to know the y_data at:  [17.14414514 18.01677236]
# I received  -0.2595559038402772
#
# I want to know the y_data at:  [21.74266682 36.0637096 ]
# I received  -0.9551827056260057
#
# I want to know the y_data at:  [ 3.00921071 46.68124388]
# I received  0.3389072567111632
#
# I want to know the y_data at:  [10.0102924 20.0682771]
# I received  -0.4216036777235337
#
# I want to know the y_data at:  [21.4503725  46.59019933]
# I received  0.854975013017849
#
# I want to know the y_data at:  [29.67319423  4.19311169]
# I received  -0.9924617814813368
#
# I want to know the y_data at:  [14.6274842  29.30367248]
# I received  0.9724900383844594
#
# I want to know the y_data at:  [10.91379835 34.28323428]
# I received  -0.988795902158301
#
# I want to know the y_data at:  [31.05792796 37.61275596]
# I received  -0.9965134564035878
#
# I want to know the y_data at:  [40.19342548 46.15746996]
# I received  -0.9984161422890985
#
# I want to know the y_data at:  [19.14164718  8.86876992]
# I received  0.7800570705955652
#
# I want to know the y_data at:  [45.31063257 21.25340475]
# I received  -0.21617851406743402
#
# I want to know the y_data at:  [45.63336549 42.14140713]
# I received  -0.6568394315671006
#
# I want to know the y_data at:  [40.3763786   4.63499844]
# I received  0.19784575589682432
#
# I want to know the y_data at:  [35.39321212 41.44940595]
# I received  -0.89000371353473
#
# I want to know the y_data at:  [37.75073216 20.47483798]
# I received  -0.8606551858118231
#
# I want to know the y_data at:  [31.34476053 46.91211354]
# I received  -0.12810201608649427
#
# I want to know the y_data at:  [13.73754336 43.58846522]
# I received  0.9889313070135392
#
# I want to know the y_data at:  [42.91377608 30.38556053]
# I received  0.7345487950270005
#
# I want to know the y_data at:  [22.40163598 23.22935869]
# I received  0.7548118347095736
#
# I want to know the y_data at:  [22.66263292 30.21422019]
# I received  0.06978731770634412
#
# I want to know the y_data at:  [33.29377641  8.51616327]
# I received  0.19065577213890558
#
# I want to know the y_data at:  [24.0087425  15.87073975]
# I received  -0.484568069466445
#
# I want to know the y_data at:  [4.53430141 8.16804513]
# I received  0.08247615505859365
#
# I want to know the y_data at:  [31.32808338 24.42808213]
# I received  0.8976424397746291
#
# I want to know the y_data at:  [39.87120327 39.03062741]
# I received  -0.6841825477543584
#
# I want to know the y_data at:  [26.73349335 41.40127298]
# I received  -0.8322659847529271
#
# I want to know the y_data at:  [13.03575001 12.08333871]
# I received  -0.8795498085689333
#
# I want to know the y_data at:  [12.23718806 46.41910838]
# I received  -0.7714614690974374
#
# I want to know the y_data at:  [14.64482371  5.00116746]
# I received  0.23064444274672766
#
# I want to know the y_data at:  [ 5.71844303 30.0743411 ]
# I received  -0.7192692533570858
#
# I want to know the y_data at:  [41.25928008 12.52118537]
# I received  -0.7610428932435539
#
# I want to know the y_data at:  [15.1779852  26.37231991]
# I received  -0.8348203877353575
#
# I want to know the y_data at:  [33.67497453 15.83850892]
# I received  -0.4665393084797624
#
# I want to know the y_data at:  [10.85546048 23.74668409]
# I received  0.8291164648735285
#
# I want to know the y_data at:  [19.0812455  20.89038118]
# I received  -0.018808270068396606
#
# I want to know the y_data at:  [41.28723651 19.09578532]
# I received  0.9979718389751044
#
# I want to know the y_data at:  [28.46212406 12.98688723]
# I received  -0.13054454848345393
#
# I want to know the y_data at:  [44.1812411   8.12061539]
# I received  0.8069910599202658
#
# I want to know the y_data at:  [43.61312116 14.93842687]
# I received  0.8538499419924559
#
# I want to know the y_data at:  [13.67647638 20.44180829]
# I received  -0.51220591533804
#
# I want to know the y_data at:  [35.56226521 29.95250044]
# I received  0.5878823289274815
